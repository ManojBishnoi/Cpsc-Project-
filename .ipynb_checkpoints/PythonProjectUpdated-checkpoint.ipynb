kipping line 1288: expected 2 fields, saw 3\nSkipping line 1296: expected 2 fields, saw 3\nSkipping line 1303: expected 2 fields, saw 3\nSkipping line 1349: expected 2 fields, saw 3\nSkipping line 1354: expected 2 fields, saw 3\nSkipping line 1469: expected 2 fields, saw 3\nSkipping line 1540: expected 2 fields, saw 4\nSkipping line 1550: expected 2 fields, saw 3\nSkipping line 1561: expected 2 fields, saw 3\nSkipping line 1579: expected 2 fields, saw 3\nSkipping line 1610: expected 2 fields, saw 3\nSkipping line 1622: expected 2 fields, saw 4\nSkipping line 1641: expected 2 fields, saw 3\nSkipping line 1648: expected 2 fields, saw 3\nSkipping line 1652: expected 2 fields, saw 4\nSkipping line 1706: expected 2 fields, saw 3\nSkipping line 1738: expected 2 fields, saw 3\nSkipping line 1791: expected 2 fields, saw 3\nSkipping line 1806: expected 2 fields, saw 3\nSkipping line 1863: expected 2 fields, saw 3\nSkipp ...
#    05/09/2019  \
# 0  03/09/2019
# 1  05/09/2019
# 2  05/09/2019
# 3  05/09/2019
# 4  05/09/2019
#
#    4:29 pm - Messages to this group are now secured with end-to-end encryption. Tap for more info.
# 0   5:34 pm - rashman canada created group "Langa...
# 1                 4:29 pm - rashman canada added you
# 2     4:30 pm - rashman canada added +91 82190 16358
# 3                      4:30 pm - You're now an admin
# 4   9:07 pm - dharun cls: Does anyone have any id...

# %%
data.head()
# Out:
#    05/09/2019  \
# 0  03/09/2019
# 1  05/09/2019
# 2  05/09/2019
# 3  05/09/2019
# 4  05/09/2019
#
#    4:29 pm - Messages to this group are now secured with end-to-end encryption. Tap for more info.
# 0   5:34 pm - rashman canada created group "Langa...
# 1                 4:29 pm - rashman canada added you
# 2     4:30 pm - rashman canada added +91 82190 16358
# 3                      4:30 pm - You're now an admin
# 4   9:07 pm - dharun cls: Does anyone have any id...

# %%
data.columns
# Out:
# Index(['05/09/2019', ' 4:29 pm - Messages to this group are now secured with end-to-end encryption. Tap for more info.'], dtype='object')

# %%
data.head()
# Out:
#    05/09/2019  \
# 0  03/09/2019
# 1  05/09/2019
# 2  05/09/2019
# 3  05/09/2019
# 4  05/09/2019
#
#    4:29 pm - Messages to this group are now secured with end-to-end encryption. Tap for more info.
# 0   5:34 pm - rashman canada created group "Langa...
# 1                 4:29 pm - rashman canada added you
# 2     4:30 pm - rashman canada added +91 82190 16358
# 3                      4:30 pm - You're now an admin
# 4   9:07 pm - dharun cls: Does anyone have any id...

# %%
data.rename(columns = {"05/09/2019":"Date"," 4:29 pm - Messages to this group are now secured with end-to-end encryption. Tap for more info.":"info"}, inplace = True)

# %%
# new data frame with split value columns 
new = data["info"].str.split("-", n = 1, expand = True) 
new.head()
# Out:
#            0                                                  1
# 0   5:34 pm      rashman canada created group "Langara College"
# 1   4:29 pm                            rashman canada added you
# 2   4:30 pm                rashman canada added +91 82190 16358
# 3   4:30 pm                                 You're now an admin
# 4   9:07 pm    dharun cls: Does anyone have any idea how to ...

# %%
# making separate first name column from new data frame 
data["Time"]= new[0] 
  
# making separate last name column from new data frame 
data["Message"]= new[1] 
  
# Dropping old Name columns 
data.drop(columns =["info"], inplace = True) 
  
# df display 
data.head()
# Out:
#          Date       Time                                            Message
# 0  03/09/2019   5:34 pm      rashman canada created group "Langara College"
# 1  05/09/2019   4:29 pm                            rashman canada added you
# 2  05/09/2019   4:30 pm                rashman canada added +91 82190 16358
# 3  05/09/2019   4:30 pm                                 You're now an admin
# 4  05/09/2019   9:07 pm    dharun cls: Does anyone have any idea how to ...

# %%
# new data frame with split value columns 
new = data["Message"].str.split(":", n = 1, expand = True) 
  
# making separate first name column from new data frame 
data["Name"]= new[0] 
  
# making separate last name column from new data frame 
data["Messages"]= new[1] 
  
# Dropping old Name columns 
data.drop(columns =["Message"], inplace = True) 
  
# df display 
data
# Out:
#                Date        Time  \
# 0        03/09/2019    5:34 pm
# 1        05/09/2019    4:29 pm
# 2        05/09/2019    4:30 pm
# 3        05/09/2019    4:30 pm
# 4        05/09/2019    9:07 pm
# 5       |2x +7| ≤ 1         NaN
# 6        05/09/2019    9:08 pm
# 7       -4 ≤ x ≤ -3         NaN
# 8        05/09/2019    9:09 pm
# 9        05/09/2019    9:10 pm
# 10       05/09/2019    9:10 pm
# 11       05/09/2019    9:10 pm
# 12       05/09/2019    9:10 pm
# 13       05/09/2019    9:10 pm
# 14       05/09/2019    9:11 pm
# 15       05/09/2019    9:12 pm
# 16       05/09/2019    9:21 pm
# 17       05/09/2019    9:21 pm
# 18       05/09/2019    9:21 pm
# 19       05/09/2019    9:23 pm
# 20       05/09/2019    9:23 pm
# 21       05/09/2019    9:25 pm
# 22       05/09/2019    9:28 pm
# 23       05/09/2019    9:40 pm
# 24       05/09/2019    9:41 pm
# 25       05/09/2019    9:41 pm
# 26       05/09/2019    9:44 pm
# 27       05/09/2019    9:44 pm
# 28       05/09/2019    9:44 pm
# 29       05/09/2019    9:45 pm
# ...             ...         ...
# 14587    23/07/2020    6:30 pm
# 14588    23/07/2020    6:30 pm
# 14589    23/07/2020    6:30 pm
# 14590    23/07/2020    6:30 pm
# 14591    23/07/2020    6:34 pm
# 14592    23/07/2020    7:30 pm
# 14593    23/07/2020    7:47 pm
# 14594    23/07/2020    7:48 pm
# 14595    23/07/2020    8:23 pm
# 14596    23/07/2020    8:23 pm
# 14597    23/07/2020    9:03 pm
# 14598    23/07/2020    9:25 pm
# 14599    23/07/2020    9:29 pm
# 14600    23/07/2020    9:44 pm
# 14601    23/07/2020    9:53 pm
# 14602    23/07/2020   11:07 pm
# 14603    23/07/2020   11:36 pm
# 14604    23/07/2020   11:37 pm
# 14605  See you all!         NaN
# 14606    24/07/2020   12:46 pm
# 14607    24/07/2020   12:55 pm
# 14608    24/07/2020   12:56 pm
# 14609    24/07/2020   12:56 pm
# 14610    24/07/2020   12:56 pm
# 14611    24/07/2020   12:57 pm
# 14612    24/07/2020   12:57 pm
# 14613    24/07/2020    9:29 pm
# 14614    24/07/2020    9:56 pm
# 14615    25/07/2020    8:42 pm
# 14616    26/07/2020   10:27 am
#
#                                                     Name  \
# 0         rashman canada created group "Langara College"
# 1                               rashman canada added you
# 2                   rashman canada added +91 82190 16358
# 3                                    You're now an admin
# 4                                             dharun cls
# 5                                                    NaN
# 6                                             dharun cls
# 7                                                    NaN
# 8                                             dharun cls
# 9                                             dharun cls
# 10                                                  vasu
# 11                                                  vasu
# 12                                            dharun cls
# 13                                            dharun cls
# 14                                                  vasu
# 15                                            dharun cls
# 16                                                  vasu
# 17                                                  vasu
# 18                                                  vasu
# 19                                            dharun cls
# 20                                            dharun cls
# 21                                            dharun cls
# 22                                           vivek reddy
# 23                                       +91 90414 65914
# 24                                       +91 90414 65914
# 25      +91 90414 65914 changed the subject from "Lan...
# 26                                        rashman canada
# 27                   rashman canada added Prerna Langara
# 28                       rashman canada added jasman cls
# 29                                   jaspreet cls canada
# ...                                                  ...
# 14587                                    kiran kumar cls
# 14588                                               vasu
# 14589                                               cici
# 14590                                               vasu
# 14591                                              kirra
# 14592                                    Harshad Langara
# 14593                                              kirra
# 14594                                              kirra
# 14595                                       Amir Langara
# 14596                                         jasman cls
# 14597                                              kirra
# 14598                              minoj bishnoi langara
# 14599                                       Amir Langara
# 14600                                              kirra
# 14601                                     rashman canada
# 14602                                         jasman cls
# 14603                                     Vedant Langara
# 14604                                     Vedant Langara
# 14605                                                NaN
# 14606                                     Vedant Langara
# 14607                                    Harshad Langara
# 14608                                         tuli class
# 14609                                    Roberta Langara
# 14610                                    Roberta Langara
# 14611                                    Harshad Langara
# 14612                                         tuli class
# 14613                                              kirra
# 14614                                    Harshad Langara
# 14615                                     Vedant Langara
# 14616                                jaspreet cls canada
#
#                                                 Messages
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4       Does anyone have any idea how to solve questi...
# 5                                                    NaN
# 6                              Spoiler alert: answer is
# 7                                                    NaN
# 8       But if anyone knows how to solve it.. it woul...
# 9                                     I know it's x ≤ -3
# 10                                            Let me see
# 11                                          After dinner
# 12                             But why is the -4 there..
# 13                             Where does that come in .
# 14                             Let me check after dinner
# 15                                                Ji sir
# 16                                       <Media omitted>
# 17                                       <Media omitted>
# 18                               Credit goes to your pen
# 19                                             No wonder
# 20                                                   😂😂😂
# 21                                                   JK.
# 22                                                   😂😂😂
# 23      Its becoz when u remove modulus u take both p...
# 24                               Rashman whom you added?
# 25                                                  None
# 26                                       Kiran and Aditi
# 27                                                  None
# 28                                                  None
# 29                        Any one researching on laptops
# ...                                                  ...
# 14587                                           link pls
# 14588                                               link
# 14589                      guys ben is taking attendance
# 14590                                      kirra missing
# 14591                       Yes he is annoying like that
# 14592   https://www.citynews1130.com/2020/07/23/b-c-t...
# 14593                                                  😫
# 14594                                              So bs
# 14595                                                  😁
# 14596                          Thank you @989126082632 😂
# 14597                             breakout room alert!!!
# 14598                            Thanks bro you saved me
# 14599                                    <Media omitted>
# 14600   If anyone knows how to do 4820 assignment lmk...
# 14601                             I would like to join😅😅
# 14602                     https://vm.tiktok.com/JFvnJkv/
# 14603                                    <Media omitted>
# 14604                                   *1pm Tomorrow!!*
# 14605                                                NaN
# 14606                                 *LIVE in 15 mins!*
# 14607                       Bro time of Sundays meeting?
# 14608                                               Link
# 14609                                    <Media omitted>
# 14610               https://langara.zoom.us/j/4127492743
# 14611                                    Thanks Roberta.
# 14612                                             Thanks
# 14613                   did azadeh tell us to show code?
# 14614             I think its according to the question.
# 14615                                    <Media omitted>
# 14616            Do we need to do anything for DANA 4820
#
# [14617 rows x 4 columns]

# %%
#drop NA
data.dropna(inplace=True)

# %%
#check unique students
data.Name.nunique()
# Out:
# 31

# %%
#list of the Names from series value_counts object
UniqueList =data["Name"].value_counts().keys().to_list()
print(UniqueList)
# Out:
# [' kirra', ' Roberta Langara', ' dharun cls', ' jaspreet cls canada', ' vasu', ' kiran kumar cls', ' Amir Langara', ' arsh langara', ' jasman cls', ' tuli class', ' naval clss', ' cici', ' Vedant Langara', ' rashman canada', ' nikita langara', ' harshad cls', ' Kania Langara', ' aditi jaswal', ' Kiran Gill', ' david langara', ' vivek reddy', ' Beth Langara', ' Prerna Langara', ' Edward', ' navjot canada', ' minoj bishnoi langara', ' Nicky Langara', ' Harshad Langara', ' +91 79884 37459', ' +91 82190 16358', ' +91 90414 65914']

# %%
#total unique Names in Data frame 
len(data.Name.unique())
# Out:
# 31

# %%
data.to_csv("Chat.csv", index =False)

# %%
data.head()
# Out:
#           Date       Time         Name  \
# 4   05/09/2019   9:07 pm    dharun cls
# 6   05/09/2019   9:08 pm    dharun cls
# 8   05/09/2019   9:09 pm    dharun cls
# 9   05/09/2019   9:10 pm    dharun cls
# 10  05/09/2019   9:10 pm          vasu
#
#                                              Messages
# 4    Does anyone have any idea how to solve questi...
# 6                           Spoiler alert: answer is
# 8    But if anyone knows how to solve it.. it woul...
# 9                                  I know it's x ≤ -3
# 10                                         Let me see

# %%
data['Date'] =  pd.to_datetime(data['Date'],format="%d/%m/%Y")

# %%
data.head()
# Out:
#          Date       Time         Name  \
# 4  2019-09-05   9:07 pm    dharun cls
# 6  2019-09-05   9:08 pm    dharun cls
# 8  2019-09-05   9:09 pm    dharun cls
# 9  2019-09-05   9:10 pm    dharun cls
# 10 2019-09-05   9:10 pm          vasu
#
#                                              Messages
# 4    Does anyone have any idea how to solve questi...
# 6                           Spoiler alert: answer is
# 8    But if anyone knows how to solve it.. it woul...
# 9                                  I know it's x ≤ -3
# 10                                         Let me see

# %%
def t(x):
    if x[-3:-1]=='pm' and x.split(':')[0][1:3]=='12':
        return(x[1:6])
    if x[-3:-1]=='pm' and x.split(':')[0][:2]!='12':
        return(str(int(x.split(':')[0])+12)+str(':')+str(x.split(':')[1][:2]))
    if x[-3:-1]=='am' and x.split(':')[0][1:3]=='12':
        return(str('00')+str(':')+str(x.split(':')[1][:2]))
    if x[-3:-1]=='am' and x.split(':')[0][:2]!='12' and x.split(':')[0][1:3]!='10' and x.split(':')[0][1:3]!='11':
        return(x[1:5])
    if x[-3:-1]=='am' and x.split(':')[0][1:3]=='10':
        return(x[1:6])
    if x[-3:-1]=='am' and x.split(':')[0][1:3]=='11':
        return(x[1:6])

# %%
data['Time'] = data['Time'].apply(lambda x: t(x))

# %%
data.head()
# Out:
#          Date   Time         Name  \
# 4  2019-09-05  21:07   dharun cls
# 6  2019-09-05  21:08   dharun cls
# 8  2019-09-05  21:09   dharun cls
# 9  2019-09-05  21:10   dharun cls
# 10 2019-09-05  21:10         vasu
#
#                                              Messages
# 4    Does anyone have any idea how to solve questi...
# 6                           Spoiler alert: answer is
# 8    But if anyone knows how to solve it.. it woul...
# 9                                  I know it's x ≤ -3
# 10                                         Let me see

# %%
data['Time'] = pd.to_datetime(data['Time'], format='%H:%M')

# %%
data.dtypes
# Out:
# Date        datetime64[ns]
# Time        datetime64[ns]
# Name                object
# Messages            object
# dtype: object

# %%
data.to_csv(r"FinalCorrectData.csv")

# %% [markdown]
# # Total Number of message by student

# %%
data1= pd.read_csv(r"FinalCorrectData.csv")

# %%
data1.head()
# Out:
#    Unnamed: 0        Date                 Time         Name  \
# 0           4  2019-09-05  1900-01-01 21:07:00   dharun cls
# 1           6  2019-09-05  1900-01-01 21:08:00   dharun cls
# 2           8  2019-09-05  1900-01-01 21:09:00   dharun cls
# 3           9  2019-09-05  1900-01-01 21:10:00   dharun cls
# 4          10  2019-09-05  1900-01-01 21:10:00         vasu
#
#                                             Messages
# 0   Does anyone have any idea how to solve questi...
# 1                          Spoiler alert: answer is
# 2   But if anyone knows how to solve it.. it woul...
# 3                                 I know it's x ≤ -3
# 4                                         Let me see

# %%
data1.drop(columns =["Unnamed: 0"], inplace = True)

# %%
data1.head()
# Out:
#          Date                 Time         Name  \
# 0  2019-09-05  1900-01-01 21:07:00   dharun cls
# 1  2019-09-05  1900-01-01 21:08:00   dharun cls
# 2  2019-09-05  1900-01-01 21:09:00   dharun cls
# 3  2019-09-05  1900-01-01 21:10:00   dharun cls
# 4  2019-09-05  1900-01-01 21:10:00         vasu
#
#                                             Messages
# 0   Does anyone have any idea how to solve questi...
# 1                          Spoiler alert: answer is
# 2   But if anyone knows how to solve it.. it woul...
# 3                                 I know it's x ≤ -3
# 4                                         Let me see

# %%
data1["period"] = data1["Date"].astype(str) +"/"+ data1["Time"].astype(str)

# %%
data1.head()
# Out:
#          Date                 Time         Name  \
# 0  2019-09-05  1900-01-01 21:07:00   dharun cls
# 1  2019-09-05  1900-01-01 21:08:00   dharun cls
# 2  2019-09-05  1900-01-01 21:09:00   dharun cls
# 3  2019-09-05  1900-01-01 21:10:00   dharun cls
# 4  2019-09-05  1900-01-01 21:10:00         vasu
#
#                                             Messages  \
# 0   Does anyone have any idea how to solve questi...
# 1                          Spoiler alert: answer is
# 2   But if anyone knows how to solve it.. it woul...
# 3                                 I know it's x ≤ -3
# 4                                         Let me see
#
#                            period
# 0  2019-09-05/1900-01-01 21:07:00
# 1  2019-09-05/1900-01-01 21:08:00
# 2  2019-09-05/1900-01-01 21:09:00
# 3  2019-09-05/1900-01-01 21:10:00
# 4  2019-09-05/1900-01-01 21:10:00

# %%
period = data1["period"].to_list()

# %%
DateTime = []
for i in period:
    DateTime.append(i[0:10]+" "+i[22:])

# %%
data1['Date'] =  pd.to_datetime(DateTime,format="%Y-%m-%d %H:%M:%S")

# %%
data1
# Out:
#                      Date                 Time                    Name  \
# 0     2019-09-05 21:07:00  1900-01-01 21:07:00              dharun cls
# 1     2019-09-05 21:08:00  1900-01-01 21:08:00              dharun cls
# 2     2019-09-05 21:09:00  1900-01-01 21:09:00              dharun cls
# 3     2019-09-05 21:10:00  1900-01-01 21:10:00              dharun cls
# 4     2019-09-05 21:10:00  1900-01-01 21:10:00                    vasu
# 5     2019-09-05 21:10:00  1900-01-01 21:10:00                    vasu
# 20                        Any one researching on laptops
# 21                           Now i add Prerna and Jasman
# 22                            may be we can buy together
# 23                            What about tomorrow's test
# 24               So are we adding everyone in our class?
# 25                      Will be like the official group?
# 26                                            Will this*
# 27                                       <Media omitted>
# 28                                          65 pages 😲😲😲
# 29                                               Tata 🙏🏼
# ...                                                  ...
# 13596                                              hahah
# 13597                                           link pls
# 13598                                               link
# 13599                      guys ben is taking attendance
# 13600                                      kirra missing
# 13601                       Yes he is annoying like that
# 13602   https://www.citynews1130.com/2020/07/23/b-c-t...
# 13603                                                  😫
# 13604                                              So bs
# 13605                                                  😁
# 13606                          Thank you @989126082632 😂
# 13607                             breakout room alert!!!
# 13608                            Thanks bro you saved me
# 13609                                    <Media omitted>
# 13610   If anyone knows how to do 4820 assignment lmk...
# 13611                             I would like to join😅😅
# 13612                     https://vm.tiktok.com/JFvnJkv/
# 13613                                    <Media omitted>
# 13614                                   *1pm Tomorrow!!*
# 13615                                 *LIVE in 15 mins!*
# 13616                       Bro time of Sundays meeting?
# 13617                                               Link
# 13618                                    <Media omitted>
# 13619               https://langara.zoom.us/j/4127492743
# 13620                                    Thanks Roberta.
# 13621                                             Thanks
# 13622                   did azadeh tell us to show code?
# 13623             I think its according to the question.
# 13624                                    <Media omitted>
# 13625            Do we need to do anything for DANA 4820
#
# [13626 rows x 3 columns]

# %%
#Weekdays column 
data1['Weekdays'] = data1['Date'].dt.day_name()

# %%
data1
# Out:
#                      Date                    Name  \
# 0     2019-09-05 21:07:00              dharun cls
# 1     2019-09-05 21:08:00              dharun cls
# 2     2019-09-05 21:09:00              dharun cls
# 3     2019-09-05 21:10:00              dharun cls
# 4     2019-09-05 21:10:00                    vasu
# 5     2019-09-05 21:10:00                    vasu
# 6     2019-09-05 21:10:00              dharun cls
# 7     2019-09-05 21:10:00              dharun cls
# 8     2019-09-05 21:11:00                    vasu
# 9     2019-09-05 21:12:00              dharun cls
# 10    2019-09-05 21:21:00                    vasu
# 11    2019-09-05 21:21:00                    vasu
# 12    2019-09-05 21:21:00                    vasu
# 13    2019-09-05 21:23:00              dharun cls
# 14    2019-09-05 21:23:00              dharun cls
# 15    2019-09-05 21:25:00              dharun cls
# 16    2019-09-05 21:28:00             vivek reddy
# 17    2019-09-05 21:40:00         +91 90414 65914
# 18    2019-09-05 21:41:00         +91 90414 65914
# 19    2019-09-05 21:44:00          rashman canada
# 20    2019-09-05 21:45:00     jaspreet cls canada
# 21    2019-09-05 21:45:00          rashman canada
# 22    2019-09-05 21:45:00     jaspreet cls canada
# 23    2019-09-05 21:45:00          rashman canada
# 24    2019-09-05 21:47:00              dharun cls
# 25    2019-09-05 21:48:00              dharun cls
# 26    2019-09-05 21:48:00              dharun cls
# 27    2019-09-05 21:48:00          rashman canada
# 28    2019-09-05 21:49:00         +91 90414 65914
# 29    2019-09-05 21:49:00         +91 90414 65914
# ...                   ...                     ...
# 13596 2020-07-23 18:29:00              tuli class
# 13597 2020-07-23 18:30:00         kiran kumar cls
# 13598 2020-07-23 18:30:00                    vasu
# 13599 2020-07-23 18:30:00                    cici
# 13600 2020-07-23 18:30:00                    vasu
# 13601 2020-07-23 18:34:00                   kirra
# 13612                     https://vm.tiktok.com/JFvnJkv/  Thursday
# 13613                                    <Media omitted>  Thursday
# 13614                                   *1pm Tomorrow!!*  Thursday
# 13615                                 *LIVE in 15 mins!*    Friday
# 13616                       Bro time of Sundays meeting?    Friday
# 13617                                               Link    Friday
# 13618                                    <Media omitted>    Friday
# 13619               https://langara.zoom.us/j/4127492743    Friday
# 13620                                    Thanks Roberta.    Friday
# 13621                                             Thanks    Friday
# 13622                   did azadeh tell us to show code?    Friday
# 13623             I think its according to the question.    Friday
# 13624                                    <Media omitted>  Saturday
# 13625            Do we need to do anything for DANA 4820    Sunday
#
# [13626 rows x 4 columns]

# %%
data1.to_csv(r"Datawithdatetime.csv")

# %%
#Groupby by names to get total number of messages 
Total_number_of_messages=pd.DataFrame(data1.groupby("Name")["Messages"].nunique())

#Creating a sorted dataframe 
Total_number_of_messages =pd.DataFrame(Total_number_of_messages["Messages"].sort_values(ascending=True))

# %%
# Simple horizontal Plot
fig = plt.figure(figsize=(15,10))
ax = fig.add_axes([0,0,1,1])
ax.barh(Total_number_of_messages.index,Total_number_of_messages.Messages)
plt.show()

# %%
list(data1.groupby('Weekdays').Messages.count())
# Out:
# [1169, 2318, 918, 1036, 3149, 3027, 2009]

# %%
data_Weekdays_Count=pd.DataFrame(data1.groupby('Weekdays').Messages.count())
sorter = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
sorterIndex = dict(zip(sorter,range(len(sorter))))
sorterIndex
# Out:
# {'Sunday': 0,
#  'Monday': 1,
#  'Tuesday': 2,
#  'Wednesday': 3,
#  'Thursday': 4,
#  'Friday': 5,
#  'Saturday': 6}

# %%
data_Weekdays_Count['Weekday'] = data_Weekdays_Count.index
data_Weekdays_Count['Weekday'] = data_Weekdays_Count['Weekday'].map(sorterIndex)
data_Weekdays_Count.sort_values('Weekday',inplace=True)

# %%
data_Weekdays_Count
# Out:
#            Messages  Weekday
# Weekdays
# Sunday         1036        0
# Monday         2318        1
# Tuesday        3027        2
# Wednesday      2009        3
# Thursday       3149        4
# Friday         1169        5
# Saturday        918        6

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_axes([0,0,1,1])
ax.bar(data_Weekdays_Count.index,data_Weekdays_Count.Messages)
plt.show()

# %% [markdown]
# # Term 1

# %%
#Groupby by names to get total number of messages in term1
Total_number_of_messages_term1=pd.DataFrame(data1[(data1.Date.dt.month>=9) & (data1.Date.dt.month<=12) &
                                                (data1.Date.dt.year == 2019)].groupby('Name').Messages.count())

#Creating a sorted dataframe in term1
Total_number_of_messages_term1 =pd.DataFrame(Total_number_of_messages_term1["Messages"].sort_values(ascending=True))

# Simple horizontal Plot for term1
fig = plt.figure(figsize=(15,10))
ax = fig.add_axes([0,0,1,1])
ax.barh(Total_number_of_messages_term1.index,Total_number_of_messages_term1.Messages)
plt.show()

# %% [markdown]
# # Term 2

# %%
#Groupby by names to get total number of messages in term2
Total_number_of_messages_term2=pd.DataFrame(data1[(data1.Date.dt.month>=1) & (data1.Date.dt.month<=4) &
                                                (data1.Date.dt.year == 2020)].groupby('Name').Messages.count())

#Creating a sorted dataframe in term1
Total_number_of_messages_term2 =pd.DataFrame(Total_number_of_messages_term2["Messages"].sort_values(ascending=True))

# Simple horizontal Plot for term2
fig = plt.figure(figsize=(15,10))
ax = fig.add_axes([0,0,1,1])
ax.barh(Total_number_of_messages_term2.index,Total_number_of_messages_term2.Messages)
plt.show()

# %% [markdown]
# # Term3

# %%
#Groupby by names to get total number of messages in term3
Total_number_of_messages_term3=pd.DataFrame(data1[(data1.Date.dt.month>=5) & (data1.Date.dt.month<=7) &
                                                (data1.Date.dt.year == 2020)].groupby('Name').Messages.count())

#Creating a sorted dataframe in term3
Total_number_of_messages_term3 =pd.DataFrame(Total_number_of_messages_term3["Messages"].sort_values(ascending=True))

# Simple horizontal Plot for term3
fig = plt.figure(figsize=(15,10))
ax = fig.add_axes([0,0,1,1])
ax.barh(Total_number_of_messages_term3.index,Total_number_of_messages_term3.Messages)
plt.show()

# %% [markdown]
# # Number of messages during CPSC lecture

# %%
#Groupby by names to get total number of messages in term3
Total_number_of_messages_term3=pd.DataFrame(data1[(data1.Date.dt.month>=5) & (data1.Date.dt.month<=7) &
                                                (data1.Date.dt.year == 2020) & 
                                                 (data1.Weekdays == "Monday") &
                                                ((data1.Date.dt.hour>=16)&(data1.Date.dt.minute>=30)) &
                                                ((data1.Date.dt.hour<=18)&(data1.Date.dt.minute<=30))].groupby('Name').Messages.count())

#Creating a sorted dataframe in term3
Total_number_of_messages_term3 =pd.DataFrame(Total_number_of_messages_term3["Messages"].sort_values(ascending=True))

# Simple horizontal Plot for term3
fig = plt.figure(figsize=(15,10))
ax = fig.add_axes([0,0,1,1])
ax.barh(Total_number_of_messages_term3.index,Total_number_of_messages_term3.Messages)
plt.show()

# %% [markdown]
# # Number of message during CPSC Lab

# %%
#Groupby by names to get total number of messages in term3
Total_number_of_messages_term3=pd.DataFrame(data1[(data1.Date.dt.month>=5) & (data1.Date.dt.month<=7) &
                                                (data1.Date.dt.year == 2020) & 
                                                 (data1.Weekdays == "Wednesday") &
                                                (data1.Date.dt.hour>=16) &
                                                (data1.Date.dt.hour<=18)].groupby('Name').Messages.count())

#Creating a sorted dataframe in term3
Total_number_of_messages_term3 =pd.DataFrame(Total_number_of_messages_term3["Messages"].sort_values(ascending=True))

# Simple horizontal Plot for term3
fig = plt.figure(figsize=(15,10))
ax = fig.add_axes([0,0,1,1])
ax.barh(Total_number_of_messages_term3.index,Total_number_of_messages_term3.Messages)
plt.show()

# %% [markdown]
# # Number of Messages during DANA 4830

# %%
#Groupby by names to get total number of messages in term3
Total_number_of_messages_term3=pd.DataFrame(data1[(data1.Date.dt.month>=5) & (data1.Date.dt.month<=7) &
                                                (data1.Date.dt.year == 2020) & 
                                                 ((data1.Weekdays == "Tuesday")|(data1.Weekdays == "Thursday")) &
                                                (data1.Date.dt.hour>=18) &
                                                (data1.Date.dt.hour<=20)].groupby('Name').Messages.count())

#Creating a sorted dataframe in term3
Total_number_of_messages_term3 =pd.DataFrame(Total_number_of_messages_term3["Messages"].sort_values(ascending=True))

# Simple horizontal Plot for term3
fig = plt.figure(figsize=(15,10))
ax = fig.add_axes([0,0,1,1])
ax.barh(Total_number_of_messages_term3.index,Total_number_of_messages_term3.Messages)
plt.show()

# %%
data1['Name'].unique()
# Out:
# array([' dharun cls', ' vasu', ' vivek reddy', ' +91 90414 65914',
#        ' rashman canada', ' jaspreet cls canada', ' tuli class',
#        ' Prerna Langara', ' +91 82190 16358', ' nikita langara',
#        ' navjot canada', ' Kiran Gill', ' arsh langara', ' Edward',
#        ' jasman cls', ' kirra', ' Roberta Langara', ' Harshad Langara',
#        ' minoj bishnoi langara', ' Vedant Langara', ' kiran kumar cls',
#        ' Beth Langara', ' aditi jaswal', ' naval clss', ' david langara',
#        ' harshad cls', ' Amir Langara', ' Kania Langara',
#        ' Nicky Langara', ' cici', ' +91 79884 37459'], dtype=object)

# %% [markdown]
# # Number of Messages per day

# %%
data1.shape
# Out:
# (13626, 4)
