# %%
#import necessory file 
import pandas as pd 
import numpy as np
import datetime
from datetime import datetime

# %%
#import data
data = pd.read_csv("WhatsApp Chat with PDD.DA’19.txt", error_bad_lines=False)
# Out:
# b'Skipping line 71: expected 2 fields, saw 3\nSkipping line 99: expected 2 fields, saw 3\nSkipping line 100: expected 2 fields, saw 3\nSkipping line 119: expected 2 fields, saw 3\nSkipping line 135: expected 2 fields, saw 3\nSkipping line 155: expected 2 fields, saw 3\nSkipping line 156: expected 2 fields, saw 3\nSkipping line 174: expected 2 fields, saw 3\nSkipping line 211: expected 2 fields, saw 3\nSkipping line 213: expected 2 fields, saw 3\nSkipping line 215: expected 2 fields, saw 3\nSkipping line 217: expected 2 fields, saw 3\nSkipping line 218: expected 2 fields, saw 3\nSkipping line 223: expected 2 fields, saw 3\nSkipping line 225: expected 2 fields, saw 3\nSkipping line 227: expected 2 fields, saw 3\nSkipping line 228: expected 2 fields, saw 3\nSkipping line 229: expected 2 fields, saw 3\nSkipping line 230: expected 2 fields, saw 3\nSkipping line 232: expected 2 fields, saw 3\nSkipping line 238: expected 2 fields, saw 3\nSkipping line 239: expected 2 fields, saw 3\nSkipping
# ...

# %%
data
# Out:
#         9/4/19  \
# 0       9/3/19
# 1       9/4/19
# 2       9/4/19
# 3       9/4/19
# 4       9/4/19
# ...        ...
# 12673  6/24/20
# 12674  6/24/20
# 12675  6/24/20
# 12676  6/24/20
# 12677  6/24/20
#
#        5:46 PM - Messages to this group are now secured with end-to-end encryption. Tap for more info.
# 0       5:34 PM - +91 98888 26051 created group "Lang...
# 1                    5:46 PM - Nikita Batra DA added you
# 2       5:59 PM - +91 90414 65914 added Vasu DA Lanagara
# 3              8:21 PM - jaspreet singh: <Media omitted>
# 4       8:22 PM - jaspreet singh: Hardware required f...
# ...                                                  ...
# 12673          7:19 PM - jaspreet singh: <Media omitted>
# 12674   7:40 PM - David Vazquez Data Analytics: Does ...
# 12675                  7:40 PM - jaspreet singh: no idea
# 12676   7:43 PM - Vasu DA Lanagara: Send me the Code ...
# 12677   8:08 PM - Kiran DA: Hi guys need php laravel ...
#
# [12678 rows x 2 columns]

# %%
data.columns
# Out:
# Index(['9/4/19', ' 5:46 PM - Messages to this group are now secured with end-to-end encryption. Tap for more info.'], dtype='object')

# %%
data.rename(columns = {"9/4/19":"Date"," 5:46 PM - Messages to this group are now secured with end-to-end encryption. Tap for more info.":"info"}, inplace = True)

# %%
data.head()
# Out:
#      Date                                               info
# 0  9/3/19   5:34 PM - +91 98888 26051 created group "Lang...
# 1  9/4/19                5:46 PM - Nikita Batra DA added you
# 2  9/4/19   5:59 PM - +91 90414 65914 added Vasu DA Lanagara
# 3  9/4/19          8:21 PM - jaspreet singh: <Media omitted>
# 4  9/4/19   8:22 PM - jaspreet singh: Hardware required f...

# %%
  
# new data frame with split value columns 
new = data["info"].str.split("-", n = 1, expand = True) 
  
# making separate first name column from new data frame 
data["Time"]= new[0] 
  
# making separate last name column from new data frame 
data["Message"]= new[1] 
  
# Dropping old Name columns 
data.drop(columns =["info"], inplace = True) 
  
# df display 
data
# Out:
#           Date       Time                                            Message
# 0       9/3/19   5:34 PM     +91 98888 26051 created group "Langara College"
# 1       9/4/19   5:46 PM                           Nikita Batra DA added you
# 2       9/4/19   5:59 PM              +91 90414 65914 added Vasu DA Lanagara
# 3       9/4/19   8:21 PM                     jaspreet singh: <Media omitted>
# 4       9/4/19   8:22 PM    jaspreet singh: Hardware required for this co...
# ...        ...        ...                                                ...
# 12673  6/24/20   7:19 PM                     jaspreet singh: <Media omitted>
# 12674  6/24/20   7:40 PM    David Vazquez Data Analytics: Does it include...
# 12675  6/24/20   7:40 PM                             jaspreet singh: no idea
# 12676  6/24/20   7:43 PM    Vasu DA Lanagara: Send me the Code if slider ...
# 12677  6/24/20   8:08 PM    Kiran DA: Hi guys need php laravel developer ...
#
# [12678 rows x 3 columns]

# %%
  
# new data frame with split value columns 
new = data["Message"].str.split(":", n = 1, expand = True) 
  
# making separate first name column from new data frame 
data["Name"]= new[0] 
  
# making separate last name column from new data frame 
data["Messages"]= new[1] 
  
# Dropping old Name columns 
data.drop(columns =["Message"], inplace = True) 
  
# df display 
data
# Out:
#           Date       Time                                              Name  \
# 0       9/3/19   5:34 PM    +91 98888 26051 created group "Langara College"
# 1       9/4/19   5:46 PM                          Nikita Batra DA added you
# 2       9/4/19   5:59 PM             +91 90414 65914 added Vasu DA Lanagara
# 3       9/4/19   8:21 PM                                     jaspreet singh
# 4       9/4/19   8:22 PM                                     jaspreet singh
# ...        ...        ...                                               ...
# 12673  6/24/20   7:19 PM                                     jaspreet singh
# 12674  6/24/20   7:40 PM                       David Vazquez Data Analytics
# 12675  6/24/20   7:40 PM                                     jaspreet singh
# 12676  6/24/20   7:43 PM                                   Vasu DA Lanagara
# 12677  6/24/20   8:08 PM                                           Kiran DA
#
#                                                 Messages
# ...

# %%
#drop NA
data.dropna(inplace =True)

# %%
#check unique students
data["Name"].nunique()
# Out:
# 30

# %%
#counts of Names
sum(data["Name"].value_counts())
# Out:
# 11837

# %%
#checking nUlls 
data.isnull().sum().sum()
# Out:
# 0

# %%
data['Date'] =  pd.to_datetime(data['Date'], format='%m/%d/%y')

# %%
data['Date']
# Out:
# 3       2019-09-04
# 4       2019-09-04
# 5       2019-09-04
# 6       2019-09-04
# 7       2019-09-05
#            ...
# 12673   2020-06-24
# 12674   2020-06-24
# 12675   2020-06-24
# 12676   2020-06-24
# 12677   2020-06-24
# Name: Date, Length: 11837, dtype: datetime64[ns]

# %%
data['Weekdays'] = data['Date'].dt.day_name()

# %%
data
# Out:
#             Date        Time                           Name  \
# 3     2019-09-04    8:21 PM                  jaspreet singh
# 4     2019-09-04    8:22 PM                  jaspreet singh
# 5     2019-09-04    8:22 PM                  jaspreet singh
# 6     2019-09-04    8:27 PM                Dharun Canada DA
# 7     2019-09-05   12:34 PM                  jaspreet singh
# ...          ...         ...                            ...
# 12673 2020-06-24    7:19 PM                  jaspreet singh
# 12674 2020-06-24    7:40 PM    David Vazquez Data Analytics
# 12675 2020-06-24    7:40 PM                  jaspreet singh
# 12676 2020-06-24    7:43 PM                Vasu DA Lanagara
# 12677 2020-06-24    8:08 PM                        Kiran DA
#
#                                                 Messages   Weekdays
# 3                                        <Media omitted>  Wednesday
# 4       Hardware required for this course is not that...  Wednesday
# ...

# %%
temp = data

# %%
temp
# Out:
#             Date        Time                           Name  \
# 3     2019-09-04    8:21 PM                  jaspreet singh
# 4     2019-09-04    8:22 PM                  jaspreet singh
# 5     2019-09-04    8:22 PM                  jaspreet singh
# 6     2019-09-04    8:27 PM                Dharun Canada DA
# 7     2019-09-05   12:34 PM                  jaspreet singh
# ...          ...         ...                            ...
# 12673 2020-06-24    7:19 PM                  jaspreet singh
# 12674 2020-06-24    7:40 PM    David Vazquez Data Analytics
# 12675 2020-06-24    7:40 PM                  jaspreet singh
# 12676 2020-06-24    7:43 PM                Vasu DA Lanagara
# 12677 2020-06-24    8:08 PM                        Kiran DA
#
#                                                 Messages   Weekdays
# 3                                        <Media omitted>  Wednesday
# 4       Hardware required for this course is not that...  Wednesday
# ...

# %%
temp["Date"]
# Out:
# 3       2019-09-04
# 4       2019-09-04
# 5       2019-09-04
# 6       2019-09-04
# 7       2019-09-05
#            ...
# 12673   2020-06-24
# 12674   2020-06-24
# 12675   2020-06-24
# 12676   2020-06-24
# 12677   2020-06-24
# Name: Date, Length: 11837, dtype: datetime64[ns]

# %%
temp["period"] = temp["Date"].astype(str) + temp["Time"]
temp["period"]
# Out:
# 3         2019-09-04 8:21 PM
# 4         2019-09-04 8:22 PM
# 5         2019-09-04 8:22 PM
# 6         2019-09-04 8:27 PM
# 7        2019-09-05 12:34 PM
#                  ...
# 12673     2020-06-24 7:19 PM
# 12674     2020-06-24 7:40 PM
# 12675     2020-06-24 7:40 PM
# 12676     2020-06-24 7:43 PM
# 12677     2020-06-24 8:08 PM
# Name: period, Length: 11837, dtype: object

# %%
#new data frame with split value columns 
new = temp["period"].str.split(expand = True) 
  
#making separate first name column from new data frame 
temp["timestamp"]= new[0] 
  
#making separate last name column from new data frame 
temp["PmAm"]= new[1] 
  
#Dropping old Name columns 
#temp.drop(columns =["perio"], inplace = True) 
  
#df display 
temp
# Out:
#             Date        Time                           Name  \
# 3     2019-09-04    8:21 PM                  jaspreet singh
# 4     2019-09-04    8:22 PM                  jaspreet singh
# 5     2019-09-04    8:22 PM                  jaspreet singh
# 6     2019-09-04    8:27 PM                Dharun Canada DA
# 7     2019-09-05   12:34 PM                  jaspreet singh
# ...          ...         ...                            ...
# 12673 2020-06-24    7:19 PM                  jaspreet singh
# 12674 2020-06-24    7:40 PM    David Vazquez Data Analytics
# 12675 2020-06-24    7:40 PM                  jaspreet singh
# 12676 2020-06-24    7:43 PM                Vasu DA Lanagara
# 12677 2020-06-24    8:08 PM                        Kiran DA
#
#                                                 Messages   Weekdays  \
# 3                                        <Media omitted>  Wednesday
# 4       Hardware required for this course is not that...  Wednesday
# ...

# %%
temp["timestamp"]
# Out:
# 3        2019-09-04
# 4        2019-09-04
# 5        2019-09-04
# 6        2019-09-04
# 7        2019-09-05
#             ...
# 12673    2020-06-24
# 12674    2020-06-24
# 12675    2020-06-24
# 12676    2020-06-24
# 12677    2020-06-24
# Name: timestamp, Length: 11837, dtype: object

# %%
temp['newdate'] =  pd.to_datetime(temp['period'], format='%Y/%m/%d %H:%M:%p')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     431             try:
# --> 432                 values, tz = conversion.datetime_to_datetime64(arg)
#     433                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-171-7cec0258be0b> in <module>
# ----> 1 temp['newdate'] =  pd.to_datetime(temp['period'], format='%Y/%m/%d %H:%M:%p')
#       2
#
# ...

# %%
# new data frame with split value columns 
#new = data["Time"].str.split(expand = True) 
  
# making separate first name column from new data frame 
#data["Hours"]= new[0] 
  
# making separate last name column from new data frame 
#data["PmAm"]= new[1] 
  
# Dropping old Name columns 
#data.drop(columns =["eveOrMor"], inplace = True) 
  
# df display 
#data
# Out:
#             Date        Time                           Name  \
# 3     2019-09-04    8:21 PM                  jaspreet singh
# 4     2019-09-04    8:22 PM                  jaspreet singh
# 5     2019-09-04    8:22 PM                  jaspreet singh
# 6     2019-09-04    8:27 PM                Dharun Canada DA
# 7     2019-09-05   12:34 PM                  jaspreet singh
# ...          ...         ...                            ...
# 12673 2020-06-24    7:19 PM                  jaspreet singh
# 12674 2020-06-24    7:40 PM    David Vazquez Data Analytics
# 12675 2020-06-24    7:40 PM                  jaspreet singh
# 12676 2020-06-24    7:43 PM                Vasu DA Lanagara
# 12677 2020-06-24    8:08 PM                        Kiran DA
#
#                                                 Messages   Weekdays  Hours  \
# 3                                        <Media omitted>  Wednesday   8:21
# 4       Hardware required for this course is not that...  Wednesday   8:22
# ...

# %%
data['Hours'] =  pd.to_datetime(data['Hours'], format='%H:%M')

# %%
data['Hours'] = pd.to_datetime(data.Hours)

# %%
temp =data

# %% [markdown]
# temp

# %%
temp
# Out:
#             Date        Time                           Name  \
# 3     2019-09-04    8:21 PM                  jaspreet singh
# 4     2019-09-04    8:22 PM                  jaspreet singh
# 5     2019-09-04    8:22 PM                  jaspreet singh
# 6     2019-09-04    8:27 PM                Dharun Canada DA
# 7     2019-09-05   12:34 PM                  jaspreet singh
# ...          ...         ...                            ...
# 12673 2020-06-24    7:19 PM                  jaspreet singh
# 12674 2020-06-24    7:40 PM    David Vazquez Data Analytics
# 12675 2020-06-24    7:40 PM                  jaspreet singh
# 12676 2020-06-24    7:43 PM                Vasu DA Lanagara
# 12677 2020-06-24    8:08 PM                        Kiran DA
#
#                                                 Messages   Weekdays  \
# 3                                        <Media omitted>  Wednesday
# 4       Hardware required for this course is not that...  Wednesday
# ...

# %%
lineplot()

# %%
temp["period"] = df["Year"] + df["quarter"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-148-fcd84d65891b> in <module>
#       1 import datetime as dt
# ----> 2 temp['Hours'] = temp['Hours'].apply(lambda x: (dt.datetime.combine(dt.datetime(1,1,1), x,) + dt.timedelta(hours=3,minutes=0)).time())
#       3 temp
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-148-fcd84d65891b> in <lambda>(x)
#       1 import datetime as dt
# ...

# %%
from datetime import datetime, timedelta
temp['Hours'] = pd.to_timedelta(temp['Hours'].astype(str)) + pd.to_timedelta('12:00')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.array_to_timedelta64()
#
# pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.parse_timedelta_string()
#
# ValueError: only leading negative signs are allowed
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-598655a75498> in <module>
# ----> 1 temp['Hours'] = pd.to_timedelta(temp['Hours'].astype(str)) + pd.to_timedelta('12:00')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/tools/timedeltas.py in to_timedelta(arg, unit, errors)
#      92         return arg
#      93     elif isinstance(arg, ABCSeries):
# ---> 94         values = _convert_listlike(arg._values, unit=unit, errors=errors)
# ...

# %%
print(temp["Hours"])
# Out:
# 3       1900-01-01 08:21:00
# 4       1900-01-01 08:22:00
# 5       1900-01-01 08:22:00
# 6       1900-01-01 08:27:00
# 7       1900-01-01 12:34:00
#                 ...
# 12673   1900-01-01 07:19:00
# 12674   1900-01-01 07:40:00
# 12675   1900-01-01 07:40:00
# 12676   1900-01-01 07:43:00
# 12677   1900-01-01 08:08:00
# Name: Hours, Length: 11837, dtype: datetime64[ns]
